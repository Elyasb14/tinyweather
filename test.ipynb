# %%
import datetime

def save_data(self, data: dict): 
    def get_timestamp() -> dict:
        x = datetime.datetime.now()
        keys = ["date", "time"]
        values = x.strftime("%m/%d/%Y, %H:%M:%S").replace(",", "").split(" ")
        return {value[0]: value[1] for value in zip(keys, values)}
    data = self.parse_data
    timestamp = get_timestamp()
    return data | timestamp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 13
#      10     timestamp = get_timestamp()
#      11     data = data | timestamp
# ---> 13 save_data(data=stuff)
#
# NameError: name 'stuff' is not defined
